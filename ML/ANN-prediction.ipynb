# %%
######################## ANN Algorithm ###################################
#Library Importing
import numpy as np
import pandas as pd
import keras
#import tensorflow
import sklearn
#Data Importing

data=pd.read_csv("inputAllR01.csv")
X=data.drop(['Depth'],axis=1)
y=data['Depth']

#Data Preprocessing

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.1)


from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

#Model Initialization
from keras.layers import Dense
from keras.models import Sequential
Neural_Network=Sequential()
Neural_Network.add(Dense(units=4,activation='relu',kernel_initializer='uniform',input_dim=7))
Neural_Network.add(Dense(units=4,activation='relu',kernel_initializer='uniform'))
Neural_Network.add(Dense(units=1,activation='relu',kernel_initializer='uniform'))
Neural_Network.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])

## Model Fitting and Prediction

Neural_Network.fit(X_train,y_train,batch_size=32, epochs=100)
pred=Neural_Network.predict(X_test)

print(pred)

##########################################################################################
#print Actual and predicted and difference
actual=np.array(y_test)

#print(result)
#print(len(X_test))
#print(pred)
#import matplotlib.pyplot as plt
#plt.plot(actual)
#plt.ylabel('some numbers')
#plt.show()
actual=np.reshape(actual,(-1,1))
#####################################
outputArray = [[0 for i in range(3)] for j in range(len(actual))] 


for i in range(0,len(actual)-1):
    
    #print(actual[i][0],"-",pred[i][0],"=",actual[i][0]-pred[i][0])
    if i==0:
        
        outputArray[i][0]="Id";
        outputArray[i][1]="Actual"
        outputArray[i][2]="Predicted"
    outputArray[i][0]=i+1;
    outputArray[i][1]=actual[i][0]
    outputArray[i][2]=pred[i][0]
    #outputArray[i][2]=actual[i][0]-pred[i][0]
    
np.savetxt('plotoutputAllR01.csv', outputArray, delimiter=',', fmt='%f')
#########################################################################################

from sklearn.metrics import mean_squared_error
print("\n Mean Squared Error:",mean_squared_error(y_test,pred))
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 1.4436 - accuracy: 0.2281
# Epoch 2/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1244 - accuracy: 0.4379 0s - loss: 0.1247 - ac
# Epoch 3/100
# 18000/18000 [==============================] - 1s 29us/step - loss: 0.1218 - accuracy: 0.4393
# Epoch 4/100
# 18000/18000 [==============================] - 1s 28us/step - loss: 0.1209 - accuracy: 0.4384
# Epoch 5/100
# 18000/18000 [==============================] - 1s 28us/step - loss: 0.1206 - accuracy: 0.4381
# Epoch 6/100
# 18000/18000 [==============================] - 1s 29us/step - loss: 0.1203 - accuracy: 0.4372
# Epoch 7/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1198 - accuracy: 0.4384
# Epoch 8/100
# 18000/18000 [==============================] - 1s 28us/step - loss: 0.1198 - accuracy: 0.4384
# Epoch 9/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1194 - accuracy: 0.4389
# Epoch 10/100
# 18000/18000 [==============================] - 1s 29us/step - loss: 0.1190 - accuracy: 0.4400
# Epoch 11/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1188 - accuracy: 0.4407
# Epoch 12/100
# 18000/18000 [==============================] - 1s 29us/step - loss: 0.1188 - accuracy: 0.4405
# Epoch 13/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1186 - accuracy: 0.4406
# Epoch 14/100
# 18000/18000 [==============================] - 1s 29us/step - loss: 0.1183 - accuracy: 0.4423
# Epoch 15/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1182 - accuracy: 0.4408
# Epoch 16/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1179 - accuracy: 0.4415
# Epoch 17/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1178 - accuracy: 0.4422
# Epoch 18/100
# 18000/18000 [==============================] - 1s 38us/step - loss: 0.1177 - accuracy: 0.4418
# Epoch 19/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1177 - accuracy: 0.4421
# Epoch 20/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1177 - accuracy: 0.4416
# Epoch 21/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1176 - accuracy: 0.4434
# Epoch 22/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1174 - accuracy: 0.4416
# Epoch 23/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1170 - accuracy: 0.4436
# Epoch 24/100
# 18000/18000 [==============================] - 1s 36us/step - loss: 0.1170 - accuracy: 0.4429
# Epoch 25/100
# 18000/18000 [==============================] - 1s 37us/step - loss: 0.1167 - accuracy: 0.4421
# Epoch 26/100
# 18000/18000 [==============================] - 1s 40us/step - loss: 0.1160 - accuracy: 0.4441
# Epoch 27/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1159 - accuracy: 0.4417
# Epoch 28/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1159 - accuracy: 0.4430
# Epoch 29/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1159 - accuracy: 0.4432
# Epoch 30/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1157 - accuracy: 0.4429
# Epoch 31/100
# 18000/18000 [==============================] - 1s 38us/step - loss: 0.1155 - accuracy: 0.4424
# Epoch 32/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1155 - accuracy: 0.4430
# Epoch 33/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1156 - accuracy: 0.4436
# Epoch 34/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1153 - accuracy: 0.4433
# Epoch 35/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1153 - accuracy: 0.4427
# Epoch 36/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1154 - accuracy: 0.4428
# Epoch 37/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1150 - accuracy: 0.4418
# Epoch 38/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1150 - accuracy: 0.4430
# Epoch 39/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1150 - accuracy: 0.4439
# Epoch 40/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1151 - accuracy: 0.4439
# Epoch 41/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1150 - accuracy: 0.4428
# Epoch 42/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1149 - accuracy: 0.4422
# Epoch 43/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1147 - accuracy: 0.4430
# Epoch 44/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1149 - accuracy: 0.4427
# Epoch 45/100
# 18000/18000 [==============================] - 1s 35us/step - loss: 0.1149 - accuracy: 0.4437
# Epoch 46/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1148 - accuracy: 0.4424
# Epoch 47/100
# 18000/18000 [==============================] - 1s 37us/step - loss: 0.1147 - accuracy: 0.4429
# Epoch 48/100
# 18000/18000 [==============================] - 1s 36us/step - loss: 0.1146 - accuracy: 0.4435
# Epoch 49/100
# 18000/18000 [==============================] - 1s 35us/step - loss: 0.1144 - accuracy: 0.4429
# Epoch 50/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1143 - accuracy: 0.4432
# Epoch 51/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1145 - accuracy: 0.4438
# Epoch 52/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1141 - accuracy: 0.4438
# Epoch 53/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1129 - accuracy: 0.4428
# Epoch 54/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1118 - accuracy: 0.4416
# Epoch 55/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1110 - accuracy: 0.4429
# Epoch 56/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1107 - accuracy: 0.4425
# Epoch 57/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1103 - accuracy: 0.4426
# Epoch 58/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1104 - accuracy: 0.4418
# Epoch 59/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1100 - accuracy: 0.4422
# Epoch 60/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1098 - accuracy: 0.4418
# Epoch 61/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1098 - accuracy: 0.4419
# Epoch 62/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1096 - accuracy: 0.4415
# Epoch 63/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1092 - accuracy: 0.4424
# Epoch 64/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1094 - accuracy: 0.4416
# Epoch 65/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1094 - accuracy: 0.4413
# Epoch 66/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1093 - accuracy: 0.4417
# Epoch 67/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1094 - accuracy: 0.4416
# Epoch 68/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1093 - accuracy: 0.4408
# Epoch 69/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1090 - accuracy: 0.4415
# Epoch 70/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1092 - accuracy: 0.4407
# Epoch 71/100
# 18000/18000 [==============================] - 1s 35us/step - loss: 0.1090 - accuracy: 0.4414
# Epoch 72/100
# 18000/18000 [==============================] - 1s 39us/step - loss: 0.1088 - accuracy: 0.4412
# Epoch 73/100
# 18000/18000 [==============================] - 1s 30us/step - loss: 0.1089 - accuracy: 0.4418
# Epoch 74/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1088 - accuracy: 0.4419
# Epoch 75/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1090 - accuracy: 0.4411
# Epoch 76/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1085 - accuracy: 0.4413
# Epoch 77/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1085 - accuracy: 0.4424
# Epoch 78/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1085 - accuracy: 0.4414
# Epoch 79/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1086 - accuracy: 0.4415
# Epoch 80/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1086 - accuracy: 0.4419
# Epoch 81/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1085 - accuracy: 0.4415
# Epoch 82/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1083 - accuracy: 0.4417
# Epoch 83/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1085 - accuracy: 0.4408
# Epoch 84/100
# 18000/18000 [==============================] - 1s 31us/step - loss: 0.1083 - accuracy: 0.4416
# Epoch 85/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1084 - accuracy: 0.4418
# Epoch 86/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1083 - accuracy: 0.4413
# Epoch 87/100
# 18000/18000 [==============================] - 1s 37us/step - loss: 0.1084 - accuracy: 0.4423
# Epoch 88/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1084 - accuracy: 0.4410
# Epoch 89/100
# 18000/18000 [==============================] - 1s 35us/step - loss: 0.1085 - accuracy: 0.4413
# Epoch 90/100
# 18000/18000 [==============================] - 1s 37us/step - loss: 0.1080 - accuracy: 0.4417
# Epoch 91/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1082 - accuracy: 0.4414
# Epoch 92/100
# 18000/18000 [==============================] - 1s 33us/step - loss: 0.1083 - accuracy: 0.4415
# Epoch 93/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1081 - accuracy: 0.4416
# Epoch 94/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1082 - accuracy: 0.4416
# Epoch 95/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1082 - accuracy: 0.4412
# Epoch 96/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1083 - accuracy: 0.4413
# Epoch 97/100
# 18000/18000 [==============================] - 1s 32us/step - loss: 0.1082 - accuracy: 0.4411
# Epoch 98/100
# 18000/18000 [==============================] - 1s 36us/step - loss: 0.1082 - accuracy: 0.4413
# Epoch 99/100
# 18000/18000 [==============================] - 1s 38us/step - loss: 0.1081 - accuracy: 0.4423
# Epoch 100/100
# 18000/18000 [==============================] - 1s 34us/step - loss: 0.1081 - accuracy: 0.4419
# [[1.9449794 ]
#  [1.7746893 ]
#  [1.7671071 ]
#  ...
#  [0.74888194]
#  [2.0488796 ]
#  [2.901528  ]]
#
#  Mean Squared Error: 0.10123927633574646
